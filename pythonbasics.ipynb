# %%
age=20
if age>=18:
  print("Adult")
# Out:
# Adult

# %%
age=16
if age>=18:
  print("eligible")

else:
    print("not eligible")
# Out:
# not eligible

# %%
marks=72
if marks>=90:
  print("A+")
elif marks>=75:
    print("A")
elif marks>=60:
      print("B")
elif marks>=50:
      print("C")
else:
        print("fail")
# Out:
# B

# %%
age=25
fare = 80
if age>=18 and fare>=50:
  print("condition satisfied")
# Out:
# condition satisfied

# %%
age=25
survived=1
if age>=18:
  if survived ==1:
    print("adult survivor")
# Out:
# adult survivor

# %% [markdown]
# LISTS
# ordered,indexed,mutable,can contasinduplicate values

# %%
my_list=[]
my_list
# Out:
# []

# %%
ages=[22,38,36,35,35]
names=["ANUSHKA DWIVEDI","ANTRA YADAV","TASHU BHADAURIA"]
mixed=[10,"python",3.5,True]
print(names)
# Out:
# ['ANUSHKA DWIVEDI', 'ANTRA YADAV', 'TASHU BHADAURIA']

# %%
print(ages)
print(names)
print(mixed)
# Out:
# [22, 38, 27, 35, 35]
# ['upman', 'yuvraaj', 'upman', 'yuvraaj', 'sachin', 'utkarsh', 'tanvi']
# [10, 'python', 3.5, True]

# %%
print(ages[0])
print(ages[-1])
print(names[-1])
print(ages[1:4])
print(ages[:2])
print(ages[::2])
# Out:
# 22
# 35
# utkarsh
# [38, 27, 35]
# [22, 38]
# [22, 27, 35]

# %%
print(ages)
ages[2]=27
print(ages)
# Out:
# [22, 38, 36, 35, 35]
# [22, 38, 27, 35, 35]

# %%
print(names)
names.append("tanvi")
print(names)
# Out:
# ['asha', 'sachin', 'utkarsh']
# ['asha', 'sachin', 'utkarsh', 'tanvi']

# %%
#insert
names.insert(1,"yuvraaj")
print(names)
names.insert(0,"upman")
# Out:
# ['asha', 'yuvraaj', 'upman', 'yuvraaj', 'yuvraaj', 'sachin', 'utkarsh', 'tanvi']

# %%
#removing/deleting items
names.remove("asha")
print(names)
# Out:
# ['upman', 'yuvraaj', 'upman', 'yuvraaj', 'yuvraaj', 'sachin', 'utkarsh', 'tanvi']

# %%
removed=names.pop(4)
print(removed)
print(names)
# Out:
# yuvraaj
# ['upman', 'yuvraaj', 'upman', 'yuvraaj', 'sachin', 'utkarsh', 'tanvi']

# %%
numbers=[40,10,30,20,10]
print(len(numbers))
# Out:
# 5

# %%
print(numbers.count(10))
# Out:
# 2

# %%
print(sum(numbers))
# Out:
# 110

# %%
numbers.sort()
print(numbers)
# Out:
# [10, 10, 20, 30, 40]

# %%
numbers.reverse()
print(numbers)
# Out:
# [40, 30, 20, 10, 10]

# %%
students=[
    ["tanvi",21,"cse"],
    ["utkarsh",22,"cse"],
    ["upman",20,"cse"],
]

# %%
print(students[0])
# Out:
# ['tanvi', 21, 'cse']

# %%
print(students[0][0])
# Out:
# tanvi

# %%
#combining lists with conditions
marks=[35,62,81,45,90]
for mark in marks:
  if mark>=50:
    print(mark,"pass")
  else:
      print(mark,"fail")
# Out:
# 35 fail
# 62 pass
# 81 pass
# 45 fail
# 90 pass

# %% [markdown]
# make a dataframe

# %%
import pandas as pd
data={
    "customer":["a1","a2","a3","a4","a5"],
    "age":[22,35,28,40,55],
    "city":["delhi","mathura","lucknow","varanasi","agra"],
    "amount":[1200,3500,5400,2130,7000],
    "rating":[4,9,3,4,7]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   customer  age      city  amount  rating
# 0       a1   22     delhi    1200       4
# 1       a2   35   mathura    3500       9
# 2       a3   28   lucknow    5400       3
# 3       a4   40  varanasi    2130       4
# 4       a5   55      agra    7000       7

# %%
df.loc[0:3,["customer","city","amount"]]
# Out:
#   customer      city  amount
# 0       a1     delhi    1200
# 1       a2   mathura    3500
# 2       a3   lucknow    5400
# 3       a4  varanasi    2130

# %%
#first 5 rows first 3 columns
df.iloc[0:5,0:3]
# Out:
#   customer  age      city
# 0       a1   22     delhi
# 1       a2   35   mathura
# 2       a3   28   lucknow
# 3       a4   40  varanasi
# 4       a5   55      agra
