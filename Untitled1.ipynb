# %%
import pandas as pd

# %%
df=pd.read_csv('/content/archive.zip')

# %%
df.columns
# Out:
# Index(['id', 'chol', 'stab.glu', 'hdl', 'ratio', 'glyhb', 'location', 'age',
#        'gender', 'height', 'weight', 'frame', 'bp.1s', 'bp.1d', 'bp.2s',
#        'bp.2d', 'waist', 'hip', 'time.ppn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        403 non-null    int64
#  1   chol      402 non-null    float64
#  2   stab.glu  403 non-null    int64
#  3   hdl       402 non-null    float64
#  4   ratio     402 non-null    float64
#  5   glyhb     390 non-null    float64
#  6   location  403 non-null    object
#  7   age       403 non-null    int64
#  8   gender    403 non-null    object
#  9   height    398 non-null    float64
#  10  weight    402 non-null    float64
#  11  frame     391 non-null    object
#  12  bp.1s     398 non-null    float64
#  13  bp.1d     398 non-null    float64
#  14  bp.2s     141 non-null    float64
#  15  bp.2d     141 non-null    float64
#  16  waist     401 non-null    float64
#  17  hip       401 non-null    float64
#  18  time.ppn  400 non-null    float64
# ...

# %%
df.dtypes
# Out:
# id            int64
# chol        float64
# stab.glu      int64
# hdl         float64
# ratio       float64
# glyhb       float64
# location     object
# age           int64
# gender       object
# height      float64
# weight      float64
# frame        object
# bp.1s       float64
# bp.1d       float64
# bp.2s       float64
# bp.2d       float64
# waist       float64
# hip         float64
# time.ppn    float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
df.head(10)
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
# 5  1008  248.0        94  69.0    3.6   4.81  Buckingham   34    male    71.0
# 6  1011  195.0        92  41.0    4.8   4.84  Buckingham   30    male    69.0
# 7  1015  227.0        75  44.0    5.2   3.94  Buckingham   37    male    59.0
# 8  1016  177.0        87  49.0    3.6   4.84  Buckingham   45    male    69.0
# 9  1022  263.0        89  40.0    6.6   5.78  Buckingham   55  female    63.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# ...

# %%
df.tail(10)
# Out:
#         id   chol  stab.glu    hdl  ratio      glyhb location  age  gender  \
# 393  41253  192.0        85   69.0    2.8   4.380000   Louisa   51    male
# 394  41254  169.0       104   58.0    2.9   4.820000   Louisa   25  female
# 395  41500  179.0        85   50.0    3.6   4.990000   Louisa   37    male
# 396  41501  216.0        84   64.0    3.4        NaN   Louisa   54  female
# 397  41503  301.0        90  118.0    2.6   4.280000   Louisa   89  female
# 398  41506  296.0       369   46.0    6.4  16.110001   Louisa   53    male
# 399  41507  284.0        89   54.0    5.3   4.390000   Louisa   51  female
# 400  41510  194.0       269   38.0    5.1  13.630000   Louisa   29  female
# 401  41752  199.0        76   52.0    3.8   4.490000   Louisa   41  female
# 402  41756  159.0        88   79.0    2.0        NaN   Louisa   68  female
#
#      height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
df['weight']
# Out:
# 0      121.0
# 1      218.0
# 2      256.0
# 3      119.0
# 4      183.0
#        ...
# 398    173.0
# 399    154.0
# 400    167.0
# 401    197.0
# 402    220.0
# Name: weight, Length: 403, dtype: float64

# %%
df['weight'].unique
# Out:
# <bound method Series.unique of 0      121.0
# 1      218.0
# 2      256.0
# 3      119.0
# 4      183.0
#        ...
# 398    173.0
# 399    154.0
# 400    167.0
# 401    197.0
# 402    220.0
# Name: weight, Length: 403, dtype: float64>

# %%
#select Multiple Columns
df[['age','gender','height']]
# Out:
#      age  gender  height
# 0     46  female    62.0
# 1     29  female    64.0
# 2     58  female    61.0
# 3     67    male    67.0
# 4     64    male    68.0
# ..   ...     ...     ...
# 398   53    male    69.0
# 399   51  female    63.0
# 400   29  female    69.0
# 401   41  female    63.0
# 402   68  female    64.0
#
# [403 rows x 3 columns]

# %%
df['weight'].unique()
# Out:
# array([121., 218., 256., 119., 183., 190., 191., 170., 166., 202., 156.,
#        195., 165., 157., 159., 126., 196., 178., 230., 288., 185., 113.,
#        118., 252., 100., 145., 189., 174., 139., 186., 205., 214., 160.,
#        192., 253., 137., 233., 180., 219., 154., 181., 187., 167., 220.,
#        274., 217., 161., 235., 125., 102., 127., 245., 264., 142., 143.,
#        173., 223., 169., 200., 215., 151., 110., 198., 197., 203., 150.,
#        204., 212., 227., 175., 158., 263., 120., 172., 164., 244., 225.,
#        140., 325., 266., 177., 146., 105., 277., 320., 163., 232., 210.,
#        255., 308.,  nan, 123., 282., 171., 138., 179., 199., 147., 184.,
#        130., 134., 251., 114., 209., 109., 144., 201., 136., 124., 153.,
#        188., 259., 162., 141., 135., 155., 211., 115., 290., 168., 260.,
#        250., 182., 176., 128.,  99., 270., 285., 216., 239., 248., 152.,
#        237., 148., 257., 228., 289., 129., 262., 222., 224.])

# %%
df['weight'].nunique()
# Out:
# 140

# %%
#filtering rows by condition

df[df['age']>50]
# Out:
#         id   chol  stab.glu    hdl  ratio      glyhb    location  age  gender  \
# 2     1002  228.0        92   37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93   12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90   28.0    8.9   7.720000  Buckingham   64    male
# 9     1022  263.0        89   40.0    6.6   5.780000  Buckingham   55  female
# 10    1024  242.0        82   54.0    4.5   4.770000      Louisa   60  female
# ..     ...    ...       ...    ...    ...        ...         ...  ...     ...
# 396  41501  216.0        84   64.0    3.4        NaN      Louisa   54  female
# 397  41503  301.0        90  118.0    2.6   4.280000      Louisa   89  female
# 398  41506  296.0       369   46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89   54.0    5.3   4.390000      Louisa   51  female
# 402  41756  159.0        88   79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
df[(df['age']>50) & (df['gender']=='female')]
# Out:
#         id   chol  stab.glu    hdl  ratio  glyhb    location  age  gender  \
# 2     1002  228.0        92   37.0    6.2   4.64  Buckingham   58  female
# 9     1022  263.0        89   40.0    6.6   5.78  Buckingham   55  female
# 10    1024  242.0        82   54.0    4.5   4.77      Louisa   60  female
# 19    1250  196.0       206   41.0    4.8  11.24  Buckingham   62  female
# 23    1256  281.0        92   41.0    6.9   5.56  Buckingham   66  female
# ..     ...    ...       ...    ...    ...    ...         ...  ...     ...
# 391  41075  221.0       126   48.0    4.6   5.53      Louisa   59  female
# 396  41501  216.0        84   64.0    3.4    NaN      Louisa   54  female
# 397  41503  301.0        90  118.0    2.6   4.28      Louisa   89  female
# 399  41507  284.0        89   54.0    5.3   4.39      Louisa   51  female
# 402  41756  159.0        88   79.0    2.0    NaN      Louisa   68  female
#
#      height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# ...

# %%
#access rows by index
df.iloc[0:10]
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
# 5  1008  248.0        94  69.0    3.6   4.81  Buckingham   34    male    71.0
# 6  1011  195.0        92  41.0    4.8   4.84  Buckingham   30    male    69.0
# 7  1015  227.0        75  44.0    5.2   3.94  Buckingham   37    male    59.0
# 8  1016  177.0        87  49.0    3.6   4.84  Buckingham   45    male    69.0
# 9  1022  263.0        89  40.0    6.6   5.78  Buckingham   55  female    63.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# ...

# %%
#Sort by a column
df.sort_values(by='age',ascending=True).head()
# Out:
#         id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  \
# 114   4823  193.0        77  49.0    3.9   4.31      Louisa   19  female
# 250  17790  146.0        79  41.0    3.6   4.76  Buckingham   19  female
# 17    1041  230.0       112  64.0    3.6   4.53      Louisa   20    male
# 373  40804  179.0       105  60.0    3.0   4.68      Louisa   20  female
# 55    2763  193.0       106  63.0    3.1   6.35  Buckingham   20  female
#
#      height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 114    61.0   119.0   small  118.0   70.0    NaN    NaN   32.0  38.0     300.0
# 250    60.0   135.0  medium  108.0   58.0    NaN    NaN   33.0  40.0     240.0
# 17     67.0   159.0  medium  100.0   90.0    NaN    NaN   31.0  39.0    1440.0
# 373    58.0   170.0  medium  140.0  100.0  138.0   82.0   34.0  46.0     270.0
# 55     68.0   274.0   small  165.0  110.0  153.0  100.0   49.0  58.0      60.0

# %%
#Sort by a column
df.sort_values(by='age',ascending=True).tail()
# Out:
#         id   chol  stab.glu    hdl  ratio  glyhb    location  age  gender  \
# 107   4803  227.0       105   44.0    5.2   5.71      Louisa   83  female
# 364  40784  226.0       279   52.0    4.3  10.07      Louisa   84  female
# 397  41503  301.0        90  118.0    2.6   4.28      Louisa   89  female
# 69    2794  232.0       184  114.0    2.0   8.40  Buckingham   91  female
# 57    2770  165.0        94   69.0    2.4   4.98  Buckingham   92  female
#
#      height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 107    59.0   125.0  medium  150.0   90.0  156.0   88.0   35.0  40.0     300.0
# 364    60.0   192.0   small  144.0   88.0  146.0   82.0   41.0  48.0     210.0
# 397    61.0   115.0  medium  218.0   90.0  238.0   90.0   31.0  41.0     210.0
# 69     61.0   127.0     NaN  170.0   82.0    NaN    NaN   35.0  38.0     120.0
# 57     62.0   217.0   large  160.0   82.0    NaN    NaN   51.0  51.0     180.0

# %%
#count values
df['age'].value_counts()
# Out:
# age
# 40    16
# 41    13
# 36    13
# 43    13
# 37    11
#       ..
# 91     1
# 69     1
# 81     1
# 84     1
# 89     1
# Name: count, Length: 68, dtype: int64

# %%
#Group by and Aggregrate
df.groupby('age').mean(10)
# Out:
#                id        chol    stab.glu         hdl     ratio      glyhb  \
# age
# 19   11306.500000  169.500000   78.000000   45.000000  3.750000   4.535000
# 20   17641.300000  186.600000   90.800000   67.100000  2.910000   4.600000
# 21   15341.500000  182.333333   86.500000   60.166667  3.166667   4.378333
# 22   10050.200000  182.600000   76.600000   55.600000  3.460000   4.046000
# 23   13878.714286  187.000000   83.285714   42.571429  4.500000   4.634286
# ..            ...         ...         ...         ...       ...        ...
# 83    4803.000000  227.000000  105.000000   44.000000  5.200000   5.710000
# 84   40784.000000  226.000000  279.000000   52.000000  4.300000  10.070000
# 89   41503.000000  301.000000   90.000000  118.000000  2.600000   4.280000
# 91    2794.000000  232.000000  184.000000  114.000000  2.000000   8.400000
# 92    2770.000000  165.000000   94.000000   69.000000  2.400000   4.980000
#
# ...

# %%
#group by aggreagate
df.groupby('age').mean(numeric_only=True)
# Out:
#                id        chol    stab.glu         hdl     ratio      glyhb  \
# age
# 19   11306.500000  169.500000   78.000000   45.000000  3.750000   4.535000
# 20   17641.300000  186.600000   90.800000   67.100000  2.910000   4.600000
# 21   15341.500000  182.333333   86.500000   60.166667  3.166667   4.378333
# 22   10050.200000  182.600000   76.600000   55.600000  3.460000   4.046000
# 23   13878.714286  187.000000   83.285714   42.571429  4.500000   4.634286
# ..            ...         ...         ...         ...       ...        ...
# 83    4803.000000  227.000000  105.000000   44.000000  5.200000   5.710000
# 84   40784.000000  226.000000  279.000000   52.000000  4.300000  10.070000
# 89   41503.000000  301.000000   90.000000  118.000000  2.600000   4.280000
# 91    2794.000000  232.000000  184.000000  114.000000  2.000000   8.400000
# 92    2770.000000  165.000000   94.000000   69.000000  2.400000   4.980000
#
# ...
